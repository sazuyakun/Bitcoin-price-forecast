# %%
import ta
import numpy as np
import pandas as pd

# %%
# random integers
a = np.random.random(100) * 10

# %%
a = pd.Series(a)

# %%
a.rolling(3).mean().fillna(0)
# Out:
# 0    0.000000
# 1    0.000000
# 2    5.664093
# 3    8.184576
# 4    6.347949
# 5    6.153528
# 6    6.472262
# 7    8.560296
# 8    9.387499
# 9    8.997871
# dtype: float64

# %%
import matplotlib.pyplot as plt

plt.plot(a)

# %%
plt.plot(a.rolling(3).mean())

# %%
a.rolling(3).mean()
# Out:
# 0          NaN
# 1          NaN
# 2     2.968080
# 3     3.673223
# 4     3.576738
#         ...
# 95    6.219910
# 96    7.952807
# 97    8.397880
# 98    8.793107
# 99    6.633674
# Length: 100, dtype: float64
